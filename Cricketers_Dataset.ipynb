# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush8587/T20-world-cup2022-analysis/blob/main/Cricketers_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
base_url = "https://cricket.sportmonks.com/api/v2.0/players?api_token=TWiEIvX7iZ2hno1xo25tDyduQsm2MKoUp6F8dEKpc1GRvHAGWdW24ES3oGKP"
response=requests.get(base_url)

# %%
import pandas as pd
from IPython.display import display, Image
def display_images(url):
    display(Image(url=url))

# %%
import json

# %%
players=pd.DataFrame(response.json()['data'])[['country_id','fullname','image_path','gender','battingstyle','bowlingstyle']]

# %%
players.rename(columns={'image_path':'player_image','fullname':'name'},inplace=True)
players
# Out:
#        country_id                          name  \
# 0           52126                 Ahmed Shehzad
# 1           52126                     Anwar Ali
# 2           52126                 Sarfraz Ahmed
# 3           52126                     Azhar Ali
# 4           52126                  Fakhar Zaman
# ...           ...                           ...
# 18042      153732  Trisha Yeadukondala Poojitha
# 18043      153732                  Priya Mishra
# 18044      153732               Tarannum Pathan
# 18045        1004          Ishwarjot Singh Sohi
# 18046        1004            Uday Bhagwan Singh
#
#                                             player_image gender  \
# 0      https://cdn.sportmonks.com/images/cricket/play...      m
# 1      https://cdn.sportmonks.com/images/cricket/play...      m
# 2      https://cdn.sportmonks.com/images/cricket/play...      m
# 3      https://cdn.sportmonks.com/images/cricket/play...      m
# ...

# %%
base_url="https://cricket.sportmonks.com/api/v2.0/countries?api_token=TWiEIvX7iZ2hno1xo25tDyduQsm2MKoUp6F8dEKpc1GRvHAGWdW24ES3oGKP"
country=pd.DataFrame(requests.get(base_url).json()['data'])[['id','name','image_path']]

# %%
country.rename(columns={'id':'country_id','image_path':'country_image','name':'country'},inplace=True)
country
# Out:
#      country_id                      country  \
# 0             2                       Poland
# 1             5                       Brazil
# 2            11                      Germany
# 3            17                       France
# 4            20                     Portugal
# ..          ...                          ...
# 239    32396817              North Macedonia
# 240    32533155                     Eswatini
# 241    34319255  Falkland Islands (Malvinas)
# 242    37176064                       Tuvalu
# 243    37200394              Kyrgyz Republic
#
#                                          country_image
# 0    https://cdn.sportmonks.com/images/countries/pn...
# 1    https://cdn.sportmonks.com/images/countries/pn...
# 2    https://cdn.sportmonks.com/images/countries/pn...
# 3    https://cdn.sportmonks.com/images/countries/pn...
# 4    https://cdn.sportmonks.com/images/countries/pn...
# ..                                                 ...
# ...

# %%
world=pd.merge(players,country,on='country_id')

# %%
world
# Out:
#        country_id                  name  \
# 0           52126         Ahmed Shehzad
# 1           52126             Anwar Ali
# 2           52126         Sarfraz Ahmed
# 3           52126             Azhar Ali
# 4           52126          Fakhar Zaman
# ...           ...                   ...
# 18042       88137  Cesarie Muragajimana
# 18043       88137          Rosine Irera
# 18044       88137       Zurafat Ishimwe
# 18045       88137      Cynthia Tuyizere
# 18046      867648            Ma'ara Ave
#
#                                             player_image gender  \
# 0      https://cdn.sportmonks.com/images/cricket/play...      m
# 1      https://cdn.sportmonks.com/images/cricket/play...      m
# 2      https://cdn.sportmonks.com/images/cricket/play...      m
# 3      https://cdn.sportmonks.com/images/cricket/play...      m
# 4      https://cdn.sportmonks.com/images/cricket/play...      m
# ...                                                  ...    ...
# ...

# %%
Cricketers=world[['name','player_image','gender','battingstyle','bowlingstyle','country','country_image']]

# %%
Mens_Cricketers=Cricketers[Cricketers['gender']=='m']
Womens_Cricketers=Cricketers[Cricketers['gender']=='f']

# %%
Cricketers.to_csv('Cricketers Dataset.csv',index=False)
Mens_Cricketers.to_csv('Mens Cricketers Dataset.csv',index=False)
Womens_Cricketers.to_csv('Womens Cricketers Dataset.csv',index=False)

# %%
asia=['India','Pakistan','Sri Lanka','Nepal','Afghanistan','Bangladesh']
t20_2022=['India','Pakistan','Sri Lanka','Afghanistan','Bangladesh','Australia','England','New Zealand','Ireland Republic','South Africa','Netherlands','Zimbabwe']
odi_2023=['India','Pakistan','Sri Lanka','Afghanistan','Bangladesh','Australia','England','New Zealand','South Africa','Netherlands']

# %%
players1=pd.read_csv('/content/dim_players.csv')

# %%
India=world[world['country']=='India']
Pakistan=world[world['country']=='Pakistan']
Sri_Lanka=world[world['country']=='Sri Lanka']
Afghanistan=world[world['country']=='Afghanistam']
Bangladesh=world[world['country']=='Bangladesh']
Australia=world[world['country']=='Australia']
England=world[world['country']=='England']
New_Zealand=world[world['country']=='New Zealand']
Ireland=world[world['country']=='Ireland Republic']
South_Africa=world[world['country']=='South Africa']
Netherlands=world[world['country']=='Netherlands']
Zimbabwe=world[world['country']=='Zimbabwe']
Nepal=world[world['country']=='Nepal']

# %%
players1.sample()
# Out:
#                 name         team  image    battingStyle        bowlingStyle  \
# 166  Kane Williamson  New Zealand    NaN  Right hand Bat  Right arm Offbreak
#
#           playingRole
# 166  Top order Batter

# %%
players1.columns
# Out:
# Index(['name', 'team', 'image', 'battingStyle', 'bowlingStyle', 'playingRole'], dtype='object')

# %%
players1.drop(['image','battingStyle','bowlingStyle','team'],axis=1)
# Out:
#                       name          playingRole
# 0    Najmul Hossain Shanto     Top order Batter
# 1            Soumya Sarkar  Middle order Batter
# 2               Litton Das  Wicketkeeper Batter
# 3          Shakib Al Hasan           Allrounder
# 4             Afif Hossain           Allrounder
# ..                     ...                  ...
# 214         Shoriful Islam               Bowler
# 215              Phil Salt  Wicketkeeper Batter
# 216            Ashton Agar               Bowler
# 217       Heinrich Klaasen  Wicketkeeper Batter
# 218    Timm van der Gugten               Bowler
#
# [219 rows x 2 columns]

# %%
India
# Out:
#       country_id                    name  \
# 1562      153732             Virat Kohli
# 1563      153732            Lokesh Rahul
# 1564      153732            Prithvi Shaw
# 1565      153732          Mayank Agarwal
# 1566      153732       Cheteshwar Pujara
# ...          ...                     ...
# 4736      153732          Pankaj Barpaga
# 4737      153732            Richu Antony
# 4738      153732            Ramesh Powar
# 4739      153732  Venkatesh Margasahayam
# 4740      153732         Jaswinder Singh
#
#                                            player_image gender  \
# 1562  https://cdn.sportmonks.com/images/cricket/play...      m
# 1563  https://cdn.sportmonks.com/images/cricket/play...      m
# 1564  https://cdn.sportmonks.com/images/cricket/play...      m
# 1565  https://cdn.sportmonks.com/images/cricket/play...      m
# 1566  https://cdn.sportmonks.com/images/cricket/play...      m
# ...                                                 ...    ...
# ...

# %%
pd.merge(world,players1.drop(['image','battingStyle','bowlingStyle','team'],axis=1),on='name').drop('country_id',axis=1).to_csv('T20 World Cup 2022.csv',index=False)

# %%
T1 CODE = SWITCH(,
            "Netherlands","NT",
            "Ireland","IRE",
            "Sri Lanka","SL",
            "Australia","AUS",
            "Afghanistan","AFG",
            "India","IND",
            "Bangladesh","BAN",
            "South Africa", "SAF",
            "England", "ENG",
            "Pakistan", "PAK",
            "New Zealand", "NZ",
            "Zimbabwe", "ZIM",
            )
